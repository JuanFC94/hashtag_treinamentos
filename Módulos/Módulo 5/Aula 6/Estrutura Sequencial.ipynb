# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Alô Mundo!')
# Out:
# Alô Mundo!

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = input('Digite um número: ')
print(f'O número digitado foi {numero}')
# Out:
# Digite um número: 559
# O número digitado foi 559

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 = int(input('Digite o primeiro número: '))
numero2 = int(input('Digite o segundo número: '))
print(f'A soma dos dois números é: {numero1 + numero2}')
# Out:
# Digite o primeiro número: 559
# Digite o segundo número: 624
# A soma dos dois números é: 1183

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = float(input('Digite a primeira nota do bimestre: '))
nota2 = float(input('Digite a segunda nota do bimestre: '))
nota3 = float(input('Digite a terceira nota do bimestre: '))
nota4 = float(input('Digite a quarta nota do bimestre: '))

print(f'Sua média do bimestre foi: {(nota1 + nota2 + nota3 + nota4) / 4}')
# Out:
# Digite a primeira nota do bimestre: 10
# Digite a segunda nota do bimestre: 7.5
# Digite a terceira nota do bimestre: 6.8
# Digite a quarta nota do bimestre: 9.9
# Sua média do bimestre foi: 8.55

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = float(input('Digite o comprimento em metros que deseja converter para centímetros: '))

print(f'O comprimento {metros}m convertido em centímetros é: {metros * 100}cm')
# Out:
# Digite o comprimento em metros que deseja converter para centímetros: 9.569
# O comprimento 9.569m convertido em centímetros é: 956.9000000000001cm

# %% [markdown]
# #### 7. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura_sala = float(input('Digite a largura da sua sala: '))
comprimento_sala = float(input('Digite o comprimento da sua sala: '))

print(f'A área da sua sala em m² é: {largura_sala * comprimento_sala}m².')
# Out:
# Digite a largura da sua sala: 3
# Digite o comprimento da sua sala: 6
# A área da sua sala em m² é: 18.0m².

# %% [markdown]
# #### 8. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
horas_trabalhadas = float(input('Quantas horas você trabalhou no mês? '))
ganho_hora = float(input('Quanto você ganha por hora? '))

print(f'Seu salário mensal é: R${horas_trabalhadas * ganho_hora}')
# Out:
# Quantas horas você trabalhou no mês? 176
# Quanto você ganha por hora? 17.98
# Seu salário mensal é: R$3164.48

# %% [markdown]
# #### 9. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
graus_f = float(input('Qual temperatura em °F você quer transformar para °C? '))

print(f'Sua temperatura {graus_f}°F é equivalente a {(5 / 9) * (graus_f - 32)}°C.')
# Out:
# Qual temperatura em °F você quer transformar para °C? 133
# Sua temperatura 133.0°F é equivalente a 56.111111111111114°C.

# %% [markdown]
# #### 10. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
graus_c = float(input('Qual temperatura em °C você quer transformar para °F? '))

print(f'Sua temperatura {graus_c}°C é equivalente a {(9 / 5) * graus_c + 32}°F.')
# Out:
# Qual temperatura em °C você quer transformar para °F? 25
# Sua temperatura 25.0°C é equivalente a 77.0°F.

# %% [markdown]
# #### 12. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Qual sua altura em metros? '))

print(f'Seu peso ideal é: {72.7 * altura - 58}Kg')
# Out:
# Qual sua altura em metros? 1.59
# Seu peso ideal é: 57.593Kg

# %% [markdown]
# #### 13. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input('Qual sua altura em metros? R:'))

print(f'Se você é homem, seu peso ideal é {72.7 * altura - 58}Kg, porém se você é mulher seu peso ideal é {62.1 * altura - 44.7}Kg')
# Out:
# Qual sua altura em metros? R:1.74
# Se você é homem, seu peso ideal é 68.498Kg, porém se você é mulher seu peso ideal é 63.354Kg

# %% [markdown]
# #### 15. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
ganho_hora = float(input('Qual seu ganho por hora trabalhada? R: '))
horas_trabalhadas = int(input('Quantas horas você trabalha por mês? R: '))
# Out:
# Qual seu ganho por hora trabalhada? R: 20
# Quantas horas você trabalha por mês? R: 176

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = ganho_hora * horas_trabalhadas
print(f'Salário bruto = {salario_bruto}')
# Out:
# Salário bruto = 3520.0

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
ir = (11 / 100) * salario_bruto
print(f'Desconto de Imposto de Renda é: R${ir}')
# Out:
# Desconto de Imposto de Renda é: R$387.2

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
inss = 0.08 * salario_bruto
print(f'Desconto de INSS é: R${inss}')
# Out:
# Desconto de INSS é: R$281.6

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
sindicato = 0.05 * salario_bruto
print(f'Desconto de sindicato é: R${sindicato}')
# Out:
# Desconto de sindicato é: R$176.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
total_descontos = sindicato + inss + ir
print(f'Seu salário líquido é de: R${salario_bruto - total_descontos}')
# Out:
# Seu salário líquido é de: R$2675.2

# %% [markdown]
# #### 16. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
metros_quadrados = float(input('Quantos m² de área a ser pintada? R: '))
quantidade_latas = (metros_quadrados / 3) / 18
custo = quantidade_latas * 80
print(f'Quantidade de latas a serem compradas é {quantidade_latas} e o preço final é R${custo}')
# Out:
# Quantos m² de área a ser pintada? R: 100
# Quantidade de latas a serem compradas é 1.851851851851852 e o preço final é R$148.14814814814815

# %% [markdown]
# #### 18. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho_arquivo = float(input('Qual tamanho do arquivo em MB? R: '))
velocidade_link = int(input('Qual velocidade do link de internet em Mbps? R: '))
tempo_download = ((tamanho_arquivo * 8) / velocidade_link) / 60
print(f'O tempo para finalizar o download é de: {tempo_download} minutos')
# Out:
# Qual tamanho do arquivo em MB? R: 250000
# Qual velocidade do link de internet em Mbps? R: 1000
# O tempo para finalizar o download é de: 33.333333333333336 minutos
