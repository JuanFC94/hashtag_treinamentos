# %% [markdown]
# # Exercícios com if

# %% [markdown]
# ## 1. Cálculo de Bônus
#
# - Crie um programa que calcule e dê um print no bônus que os funcionários devem receber segundo a regra:
#
# A meta é 1000 vendas.<br>
# Se o valor de vendas for maior ou igual a meta, o valor do bônus do funcionário é 10% do valor de vendas.<br>
# Caso contrário o valor de bônus do funcionário é 0.<br>
# Print o bônus dos 3 funcionários

# %%
vendas_funcionario1 = input('Digite o valor de vendas do funcionário 1. R: ')
vendas_funcionario2 = input('Digite o valor de vendas do funcionário 2. R: ')
vendas_funcionario3 = input('Digite o valor de vendas do funcionário 3. R: ')

#crie seu código aqui
if vendas_funcionario1 and vendas_funcionario2 and vendas_funcionario3:
  if float(vendas_funcionario1) >= 1000:
    bonus = float(vendas_funcionario1) * 0.1
  else:
    bonus = 0
  print(f'O funcionário 1 ganhou {bonus} reais de bônus.')

  if float(vendas_funcionario2) >= 1000:
    bonus = float(vendas_funcionario2) * 0.1
  else:
    bonus = 0
  print(f'O funcionário 2 ganhou {bonus} reais de bônus.')

  if float(vendas_funcionario3) >= 1000:
    bonus = float(vendas_funcionario3) * 0.1
  else:
    bonus = 0
  print(f'O funcionário 3 ganhou {bonus} reais de bônus.')
else:
  print('Preencha as vendas dos funcionários 1, 2 e 3!')
# Out:
# Digite o valor de vendas do funcionário 1. R: 1254
# Digite o valor de vendas do funcionário 2. R: 5463
# Digite o valor de vendas do funcionário 3. R: 2652
# O funcionário 1 ganhou 125.4 reais de bônus.
# O funcionário 2 ganhou 546.3000000000001 reais de bônus.
# O funcionário 3 ganhou 265.2 reais de bônus.

# %% [raw]
# Resposta:
# O funcionário 1 ganhou 100 de bônus
# O funcionário 2 ganhou 0 de bônus
# O funcionário 3 ganhou 270 de bônus

# %% [markdown]
# ## 2. Cálculo de bônus com uma nova regra
#
# - Agora, crie um novo código que calcule e dê um print no bônus dos funcionários novamente. Porém há uma nova regra nesse 2º caso:
#
# A meta é 1000 vendas<br>
# Agora, os funcionários que venderem muito acima da meta ganham mais bônus do que os outros. Então o bônus é definido da seguinte forma:<br>
#
# - Se vendas funcionário for maior ou igual a 2000, então o bônus é de 15% sobre o valor de vendas
# - Se vendas funcionário for menor do que 2000 e maior ou igual a 1000, então o bônus é de 10% sobre o valor de vendas
# - Se vendas funcionário for menos do que 1000 então o bônus do funcionário é de 0.
#
# Use as mesmas variáveis de vendas_funcionários

# %%
vendas_funcionario1 = 1000
vendas_funcionario2 = 500
vendas_funcionario3 = 2500

#crie seu código aqui
#obs: há 2 formas de fazer, com if dentro de if ou então com if e elif. Escolha a que você preferir


#####if dentro de if
if vendas_funcionario1 >= 1000:
  if vendas_funcionario1 >= 2000:
    bonus = vendas_funcionario1 * 0.15
  else:
    bonus = vendas_funcionario1 * 0.10
else:
  bonus = 0
print(f'O funcionário 1 ganhou {bonus} reais de bônus.')

if vendas_funcionario2 >= 1000:
  if vendas_funcionario2 >= 2000:
    bonus = vendas_funcionario2 * 0.15
  else:
    bonus = vendas_funcionario2 * 0.10
else:
  bonus = 0
print(f'O funcionário 2 ganhou {bonus} reais de bônus.')

if vendas_funcionario3 >= 1000:
  if vendas_funcionario3 >= 2000:
    bonus = vendas_funcionario3 * 0.15
  else:
    bonus = vendas_funcionario3 * 0.10
else:
  bonus = 0
print(f'O funcionário 3 ganhou {bonus} reais de bônus.')


################### if e elif
if vendas_funcionario1 >= 2000:
  bonus = vendas_funcionario1 * 0.15
elif vendas_funcionario1 >= 1000:
  bonus = vendas_funcionario1 * 0.10
else:
  bonus = 0
print(f'O funcionário 1 ganhou {bonus} reais de bônus.')

if vendas_funcionario2 >= 2000:
  bonus = vendas_funcionario2 * 0.15
elif vendas_funcionario2 >= 1000:
  bonus = vendas_funcionario2 * 0.10
else:
  bonus = 0
print(f'O funcionário 2 ganhou {bonus} reais de bônus.')

if vendas_funcionario3 >= 2000:
  bonus = vendas_funcionario3 * 0.15
elif vendas_funcionario3 >= 1000:
  bonus = vendas_funcionario3 * 0.10
else:
  bonus = 0
print(f'O funcionário 3 ganhou {bonus} reais de bônus.')
# Out:
# O funcionário 1 ganhou 100.0 reais de bônus.
# O funcionário 2 ganhou 0 reais de bônus.
# O funcionário 3 ganhou 375.0 reais de bônus.
# O funcionário 1 ganhou 100.0 reais de bônus.
# O funcionário 2 ganhou 0 reais de bônus.
# O funcionário 3 ganhou 375.0 reais de bônus.

# %% [raw]
# Resposta:
# O funcionário 1 ganhou 100 de bônus
# O funcionário 2 ganhou 0 de bônus
# O funcionário 3 ganhou 405 de bônus
